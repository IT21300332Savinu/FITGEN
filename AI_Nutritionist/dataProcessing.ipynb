# %%
import pandas as pd

# %%
df = pd.read_csv("meal_suggestion_meal_plans.csv")

# %%
df
# Out:
#            Breakfast Suggestion                      Lunch Suggestion  \
# 0          Upma with vegetables              Paneer wrap with veggies
# 1     Oats with banana and nuts  Chicken salad with whole grain bread
# 2          Upma with vegetables              Paneer wrap with veggies
# 3     Protein shake with banana         Chicken curry with brown rice
# 4          Upma with vegetables  Chicken salad with whole grain bread
# ...                         ...                                   ...
# 1693       Fruit and chia seeds    Zucchini noodles with tomato sauce
# 1694          Paratha with curd         Chicken curry with brown rice
# 1695      Oats with almond milk    Zucchini noodles with tomato sauce
# 1696               Egg sandwich         Chicken curry with brown rice
# 1697  Protein shake with banana         Chicken curry with brown rice
#
#                           Dinner Suggestion                 Snack Suggestion  \
# ...

# %%
unique_DS = df['Dinner Suggestion'].unique()
unique_LS = df['Lunch Suggestion'].unique()
unique_BS = df['Breakfast Suggestion'].unique()
unique_SS = df['Snack Suggestion'].unique()

# %%
# Combine all unique values
combined_unique = pd.concat([
    df['Dinner Suggestion'],
    df['Lunch Suggestion'],
    df['Breakfast Suggestion'],
    df['Snack Suggestion']
]).unique()

# %%
combined_unique
# Out:
# array(['Chapati with dal and mixed vegetables', 'Vegetable biryani',
#        'Turkey chili', 'Stuffed paneer chapati with salad',
#        'Soup with whole grain toast', 'Grilled chicken with salad',
#        'High-protein pasta', 'Light tofu stir-fry',
#        'Quinoa salad with steamed veggies', 'Paneer wrap with veggies',
#        'Chicken salad with whole grain bread',
#        'Chicken curry with brown rice', 'Rajma chawal with salad',
#        'Grilled vegetables with lentils', 'Baked fish with quinoa',
#        'Lentil curry with rice', 'Zucchini noodles with tomato sauce',
#        'Brown rice with spinach curry', 'Upma with vegetables',
#        'Oats with banana and nuts', 'Protein shake with banana',
#        'Multigrain toast with egg', 'Paratha with curd',
#        'Oats with almond milk', 'Egg sandwich', 'Fruit and chia seeds',
#        'Low-fat yogurt with berries', 'Fruit smoothie', 'Boiled eggs',
#        'Banana and peanut butter', 'Nuts and dry fruits',
# ...
